# %%
 #command arduino function
def command arduino (command):
    freq min= 500 
    freq div =1000
    sample= 100000
    FMAP = freq_map (8,1)
    FMAP_Array= FMAP[O]
    FEMAP_Max =FMAP[1]
if (command == "command1"):
       synthComplex ([freq min], [1,1,1], sample, "command.wav", 0)
        playback ("command. Way")
if (command == "command2")
     synthComplex ([freq_min+ freq_div], [1,1,1], sample, "command.wav", 0)
     playback("command.wav")
if (command== "command 3"):
     synthComplex ([ freq min+ 2*freq_div], [1,1,1], sample, "command.wav", 0)
        playback ("command.wav")
if (command== "cammand4"):
    synthComplex ([freq min+ 3*freq_div], [1,1,1], sample, "command.wav", 0)
    playback ("Command.wav")
if (command== "command5"):
    SynthComplex ([freq min+ 4*(freq div)], [1,1,1], sample, "command.wav",.0)
    playback ("comand.wav")
if (command =="command6"):
     synthComplex ([freq min+ 5*(freq_div) ,[1,1,1], sample, "command.wav", 0)
     playback ("command.wav")
if (command =="command7"):
     synthComplex ([freq min+ 6*(freq_div)], [1,1,1], sample, "command.wav", 0)
     playback (command.wav")
if (command =="command8"):
     synthComplex ([freq min+ 7*(freq_div)], [1,1,1], sample, "command.wav", 0)
     playback (command.wav")
# Out:
#   File "<ipython-input-1-b8067bec7665>", line 4
#     def command arduino (command):
#                       ^
# SyntaxError: invalid syntax

# %%
#9.1.12 convert_to_map function




def convert_to_map (freq, freq_num, freq_div, freq min):
    place 1
    mapp_int = 0
    mapp = []
##        print free
  for i in range (0,len (freq))
    val= int (freq[i])
    if (val== 10000):
          mapp.append(5555)
    if(val = 99999):
        val =999;
        place =1
        
        if(place<3):
            mapp.append(mapp_int)
            print mapp_int
        mapp_int=0
    if(val !=99999):
        oth=((val -freq_min)/freq_div)
        

         print oth
             if (place== 1)
                 mapp_ int= oth
            if (place == 2):
                 mapp_int= (oth * (10**3))+ mapp_int
            if (place == 3):
                 mappz_int= (oth *(10**6))+ mapp int
                     place= place + 1


                         print val 

                    mapp.append (val)
                     print mapp
                          output=""
        for i in range (0,len (mapp)):
              if (mapp[i]== 5555):
                output= output+ '\n';
            if (mapp[i] in FMAP_Array):
                 dec_out= int (FMAP_Array.index (mapp [i]));
                     print dec out
                if (dec_out <= 256):
                     print chr(dec out)
                        output = output+chr(dec_out)
                        print output
                        return mapp
